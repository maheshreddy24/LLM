# %%
import torch
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("gpt2")

# %%
from decoder import Decoder

# %%
config_path = 'transformer/configs/v1.yaml'
model = Decoder(config_path=config_path)

# %%
checkpoint = torch.load("/src/checkpoints/20260630_123323/epoch-2-step-375/optim.pt")
checkpoint.keys()
# Out:
# dict_keys(['epoch', 'step', 'model_state_dict', 'optimizer', 'scheduler'])

# %%
model.load_state_dict(checkpoint['model_state_dict'])
# Out:
# <All keys matched successfully>

# %%
prompt = "what is transformer?"
input_ids = tokenizer.encode(prompt)
input_ids = torch.tensor(input_ids).unsqueeze(0)
print(input_ids.shape)
# Out:
# torch.Size([1, 4])

# %%
output = model.generate(input_ids=input_ids, max_new_tokens=100)

# %%
tokenizer.decode(output[0])
# Out:
# 'what is transformer? While there is no Gemini-11-120B-Instruct-Chat, MCTF is to go up and moved for three-dimensional alignment pairs of object detection. This includes two categories: • We do not take the baseline for a mismatch but can be classified as:ফ) • The ad- portant in which the hand is of a small probability pro- pustrated in an image. The label is the number of images: the original-range image[C, all,'
